# %%
try :
    df = spark.read.format("csv")\
            .option("header",True)\
            .option("inferSchema",True)\
            .load("/FileStore/rawsource/sales_data_first_first.csv")

    df.display()

except Exception as e:
    print(f"Hey, You have an error - {e}")
# Out:
# Hey, You have an error - [PATH_NOT_FOUND] Path does not exist: dbfs:/FileStore/rawsource/sales_data_first_first.csv.

# %%
print("Hello my lovely Data Fam")
# Out:
# Hello my lovely Data Fam
