# %% [markdown]
# **Question-Create a Class to call Window Functions whenever needed and on any DataFrame**

# %%
from pyspark.sql.functions import * 
from pyspark.sql.types import * 
from pyspark.sql.window import Window

# %% [markdown]
# %md
# note--df.withColumn(
#     "dense_rank",
#     dense_rank().over(
#         Window.partitionBy("Month")
#               .orderBy("Units_Sold")
#     )
# ).display()

# %%
class window_functions:

    df = spark.read.format("csv")\
            .option("header",True)\
            .option("inderSchema",True)\
            .load("/FileStore/rawsource/sales_data_first.csv")

    
    def dense_rank_func(self,new_col,part_cols,ord_cols):

        self.df = self.df.withColumn(new_col,dense_rank().over(Window.partitionBy(part_cols).orderBy(col(ord_cols).desc())))
        return self.df 
    
    def rank_func(self,new_col,part_cols,ord_cols):

        self.df = self.df.withColumn(new_col,rank().over(Window.partitionBy(part_cols).orderBy(col(ord_cols).desc())))
        return self.df 

    def dense_rank_func(self,new_col,part_cols,ord_cols):

        self.df = self.df.withColumn(new_col,row_numberk().over(Window.partitionBy(part_cols).orderBy(col(ord_cols).desc())))
        return self.df

# %%
obj = window_functions()

# %%
obj.df = df_new

# %%
df_new = obj.dense_rank_func("dense_rank_col", "Month", "Units_Sold")

# %%
df_new.display()

# %% [markdown]
# **example -2**
# **Importing data bricks note book**
#
# Keep only class logic in notebook  and also remove all cells
#
# /Workspace/Repos/srinivas.adf120@gmail.com/Pyspark/Interview_questions/PySpark RealTime/Import
#
# use the above note book for import
