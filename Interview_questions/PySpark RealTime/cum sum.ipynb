# %%
from pyspark.sql.window import Window

# %%
df = df.withColumn("CumSum",sum("Units_Sold").over(Window.partitionBy("Month").orderBy("Month")))

df.display()

# %% [markdown]
# **It gives whole sum value for each one ---not this**

# %%
df = df.withColumn("CumSum",sum("Units_Sold").over(Window.partitionBy("Month").orderBy("Month").rowsBetween(Window.unboundedPreceding,Window.currentRow)))

df.display()
