# %% [markdown]
# **Create a DATAFRAME that should read the DATA from the DATALAKE. If there are any errors, then it should not FAIL.**

# %%
df = spark.read.format("csv")\
        .option("header", True)\
        .option("inferSchema", True)\
        .load("/FileStore/rawsource/sales_data_first.csv")

df.display()

# %% [markdown]
# **If you want  run another cell if previous file throw error also …..use try and except code ----**

# %% [markdown]
# just change file name for error

# %%
try :
    df = spark.read.format("csv")\
            .option("header",True)\
            .option("inferSchema",True)\
            .load("/FileStore/rawsource/sales_data_first_first.csv")

    df.display()

except Exception as e:
    print(f"Hey, You have an error - {e}")

# %%
print("Hello my lovely Data Fam")

# %% [markdown]
# Clicked run all----didn’t stop cell and move to another cell

# %% [markdown]
# Import Exception then you will see actual error
