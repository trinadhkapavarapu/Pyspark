# %% [markdown]
# **Create a PARAMETRIZED notebook which takes the values from the user to use it in you FILTER criteria. Also create multiple OUTPUTS based on this parameter.**

# %%
from pyspark.sql.functions import *

# %%
var_Units_Sold = [1,2,3]

# %%
df = spark.read.format("csv")\
        .option("header",True)\
        .option("inferSchema",True)\
        .load("/FileStore/rawsource/sales_data_first.csv")

df.display()

# %%
for i in var_Units_Sold:

    df = spark.read.format("csv")\
        .option("header",True)\
        .option("inferSchema",True)\
        .load("/FileStore/rawsource/sales_data_first.csv")\
        .filter(col('Units_Sold') == i)

    df.write.format("csv")\
            .mode("append")\
            .option("path",f"/FileStore/loopdata/Units_Sold = {i}")\
            .save()
